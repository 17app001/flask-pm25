# %%
import pandas as pd

# %%
api_url = 'https://sta.ci.taiwan.gov.tw/STA_AirQuality_v2/v1.0/Datastreams?$expand=Thing,Observations($orderby=phenomenonTime%20desc;$top=1)&$filter=name%20eq%20%27PM2.5%27%20and%20Thing/properties/authority%20eq%20%27%E8%A1%8C%E6%94%BF%E9%99%A2%E7%92%B0%E5%A2%83%E4%BF%9D%E8%AD%B7%E7%BD%B2%27%20and%20substringof(%27%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%B8%AC%E7%AB%99%27,Thing/name)&$count=true'

# %%
datas=pd.read_json(api_url)['value']
datas
# Out:
# 0     {'description': '細懸浮微粒 PM2.5', '@iot.id': 11, ...
# 1     {'description': '細懸浮微粒 PM2.5', '@iot.id': 29, ...
# 2     {'description': '細懸浮微粒 PM2.5', '@iot.id': 47, ...
# 3     {'description': '細懸浮微粒 PM2.5', '@iot.id': 65, ...
# 4     {'description': '細懸浮微粒 PM2.5', '@iot.id': 83, ...
#                             ...
# 72    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1307...
# 73    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1325...
# 74    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1343...
# 75    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1361...
# 76    {'description': '細懸浮微粒 PM2.5', '@iot.id': 1379...
# Name: value, Length: 77, dtype: object

# %%
len(datas)
# Out:
# 77

# %% [markdown]
# ### 取得縣市跟站點名稱

# %%
city,stationName=datas[0]['Thing']['properties']['city'],datas[0]['Thing']['properties']['stationName']
city,stationName
# Out:
# ('基隆市', '基隆')

# %% [markdown]
# ### 取得PM2.5跟更新時間

# %%
result,resultTime=datas[0]['Observations'][0]['result'],datas[0]['Observations'][0]['resultTime']
result,resultTime
# Out:
# (4, '2022-08-16T10:00:00.000Z')

# %% [markdown]
# ### 輸出所有站點資料

# %%
values=[]
for data in datas:
    city,stationName=data['Thing']['properties']['city'],data['Thing']['properties']['stationName']
    result,resultTime=data['Observations'][0]['result'],data['Observations'][0]['resultTime']
    resultTime=pd.to_datetime(resultTime).strftime('%Y-%m-%d %H:%M:%S')

    print(city,stationName,result,resultTime)
    values.append([city,stationName,result,resultTime])

values
# Out:
# 基隆市 基隆 4 2022-08-16 10:00:00
# 新北市 汐止 8 2022-08-16 10:00:00
# 新北市 萬里 6 2022-08-16 10:00:00
# 新北市 新店 14 2022-08-16 10:00:00
# 新北市 土城 13 2022-08-16 10:00:00
# 新北市 板橋 10 2022-08-16 10:00:00
# 新北市 新莊 12 2022-08-16 10:00:00
# 新北市 菜寮 17 2022-08-16 10:00:00
# 新北市 林口 9 2022-08-16 10:00:00
# 新北市 淡水 4 2022-08-16 10:00:00
# 臺北市 士林 8 2022-08-16 04:00:00
# 臺北市 中山 19 2022-08-16 10:00:00
# 臺北市 萬華 17 2022-08-16 10:00:00
# 臺北市 古亭 18 2022-08-16 10:00:00
# 臺北市 松山 11 2022-08-16 10:00:00
# 臺北市 大同 28 2022-08-16 10:00:00
# 桃園市 桃園 9 2022-08-16 10:00:00
# 桃園市 大園 4 2022-08-16 10:00:00
# 桃園市 觀音 5 2022-08-16 10:00:00
# 桃園市 平鎮 10 2022-08-16 10:00:00
# 桃園市 龍潭 10 2022-08-16 10:00:00
# 新竹縣 湖口 10 2022-08-16 10:00:00
# 新竹縣 竹東 9 2022-08-16 10:00:00
# 新竹市 新竹 8 2022-08-16 10:00:00
# 苗栗縣 頭份 0 2022-08-16 10:00:00
# 苗栗縣 苗栗 4 2022-08-16 10:00:00
# 苗栗縣 三義 5 2022-08-16 10:00:00
# 臺中市 豐原 8 2022-08-16 10:00:00
# 臺中市 沙鹿 2 2022-08-16 10:00:00
# 臺中市 大里 5 2022-08-16 10:00:00
# 臺中市 忠明 9 2022-08-16 10:00:00
# 臺中市 西屯 8 2022-08-16 10:00:00
# 彰化縣 彰化 8 2022-08-16 10:00:00
# 彰化縣 線西 6 2022-08-16 10:00:00
# 彰化縣 二林 19 2022-08-16 10:00:00
# 南投縣 南投 11 2022-08-16 10:00:00
# 雲林縣 斗六 7 2022-08-16 10:00:00
# 雲林縣 崙背 8 2022-08-16 10:00:00
# 嘉義縣 新港 11 2022-08-16 10:00:00
# 嘉義縣 朴子 10 2022-08-16 10:00:00
# 雲林縣 臺西 7 2022-08-16 10:00:00
# 嘉義市 嘉義 9 2022-08-16 10:00:00
# 臺南市 新營 9 2022-08-16 10:00:00
# 臺南市 善化 9 2022-08-16 10:00:00
# 臺南市 安南 10 2022-08-16 10:00:00
# 臺南市 臺南 7 2022-08-16 10:00:00
# 高雄市 美濃 9 2022-08-16 10:00:00
# 高雄市 橋頭 4 2022-08-16 10:00:00
# 高雄市 仁武 3 2022-08-16 10:00:00
# 高雄市 鳳山 6 2022-08-16 10:00:00
# 高雄市 大寮 5 2022-08-16 10:00:00
# 高雄市 林園 2 2022-08-16 10:00:00
# 高雄市 楠梓 2 2022-08-16 10:00:00
# 高雄市 左營 0 2022-08-16 10:00:00
# 高雄市 前金 3 2022-08-16 10:00:00
# 高雄市 前鎮 2 2022-08-16 10:00:00
# 高雄市 小港 6 2022-08-16 10:00:00
# 屏東縣 屏東 10 2022-08-16 10:00:00
# 屏東縣 潮州 11 2022-08-16 10:00:00
# 屏東縣 恆春 2 2022-08-16 10:00:00
# 臺東縣 臺東 2 2022-08-16 10:00:00
# 花蓮縣 花蓮 3 2022-08-16 10:00:00
# 臺北市 陽明 9 2022-08-16 10:00:00
# 宜蘭縣 宜蘭 8 2022-08-16 10:00:00
# 宜蘭縣 冬山 0 2022-08-16 10:00:00
# 新北市 三重 15 2022-08-16 10:00:00
# 桃園市 中壢 11 2022-08-16 10:00:00
# 南投縣 竹山 3 2022-08-16 10:00:00
# 新北市 永和 15 2022-08-16 10:00:00
# 高雄市 復興 3 2022-08-16 10:00:00
# 南投縣 埔里 9 2022-08-16 10:00:00
# 新北市 富貴角 3 2022-08-16 10:00:00
# 臺東縣 關山 0 2022-08-16 10:00:00
# 金門縣 金門 0 2022-08-16 10:00:00
# 連江縣 馬祖 7 2022-08-16 10:00:00
# 澎湖縣 馬公 8 2022-08-16 10:00:00
# 雲林縣 麥寮 1 2022-08-16 10:00:00
# [['基隆市', '基隆', 4, '2022-08-16 10:00:00'],
#  ['新北市', '汐止', 8, '2022-08-16 10:00:00'],
#  ['新北市', '萬里', 6, '2022-08-16 10:00:00'],
#  ['新北市', '新店', 14, '2022-08-16 10:00:00'],
#  ['新北市', '土城', 13, '2022-08-16 10:00:00'],
#  ['新北市', '板橋', 10, '2022-08-16 10:00:00'],
#  ['新北市', '新莊', 12, '2022-08-16 10:00:00'],
#  ['新北市', '菜寮', 17, '2022-08-16 10:00:00'],
#  ['新北市', '林口', 9, '2022-08-16 10:00:00'],
#  ['新北市', '淡水', 4, '2022-08-16 10:00:00'],
#  ['臺北市', '士林', 8, '2022-08-16 04:00:00'],
#  ['臺北市', '中山', 19, '2022-08-16 10:00:00'],
#  ['臺北市', '萬華', 17, '2022-08-16 10:00:00'],
#  ['臺北市', '古亭', 18, '2022-08-16 10:00:00'],
#  ['臺北市', '松山', 11, '2022-08-16 10:00:00'],
#  ['臺北市', '大同', 28, '2022-08-16 10:00:00'],
#  ['桃園市', '桃園', 9, '2022-08-16 10:00:00'],
#  ['桃園市', '大園', 4, '2022-08-16 10:00:00'],
#  ['桃園市', '觀音', 5, '2022-08-16 10:00:00'],
#  ['桃園市', '平鎮', 10, '2022-08-16 10:00:00'],
#  ['桃園市', '龍潭', 10, '2022-08-16 10:00:00'],
#  ['新竹縣', '湖口', 10, '2022-08-16 10:00:00'],
#  ['新竹縣', '竹東', 9, '2022-08-16 10:00:00'],
#  ['新竹市', '新竹', 8, '2022-08-16 10:00:00'],
#  ['苗栗縣', '頭份', 0, '2022-08-16 10:00:00'],
#  ['苗栗縣', '苗栗', 4, '2022-08-16 10:00:00'],
#  ['苗栗縣', '三義', 5, '2022-08-16 10:00:00'],
#  ['臺中市', '豐原', 8, '2022-08-16 10:00:00'],
#  ['臺中市', '沙鹿', 2, '2022-08-16 10:00:00'],
#  ['臺中市', '大里', 5, '2022-08-16 10:00:00'],
#  ['臺中市', '忠明', 9, '2022-08-16 10:00:00'],
#  ['臺中市', '西屯', 8, '2022-08-16 10:00:00'],
#  ['彰化縣', '彰化', 8, '2022-08-16 10:00:00'],
#  ['彰化縣', '線西', 6, '2022-08-16 10:00:00'],
#  ['彰化縣', '二林', 19, '2022-08-16 10:00:00'],
#  ['南投縣', '南投', 11, '2022-08-16 10:00:00'],
#  ['雲林縣', '斗六', 7, '2022-08-16 10:00:00'],
#  ['雲林縣', '崙背', 8, '2022-08-16 10:00:00'],
#  ['嘉義縣', '新港', 11, '2022-08-16 10:00:00'],
#  ['嘉義縣', '朴子', 10, '2022-08-16 10:00:00'],
#  ['雲林縣', '臺西', 7, '2022-08-16 10:00:00'],
#  ['嘉義市', '嘉義', 9, '2022-08-16 10:00:00'],
#  ['臺南市', '新營', 9, '2022-08-16 10:00:00'],
#  ['臺南市', '善化', 9, '2022-08-16 10:00:00'],
#  ['臺南市', '安南', 10, '2022-08-16 10:00:00'],
#  ['臺南市', '臺南', 7, '2022-08-16 10:00:00'],
#  ['高雄市', '美濃', 9, '2022-08-16 10:00:00'],
#  ['高雄市', '橋頭', 4, '2022-08-16 10:00:00'],
#  ['高雄市', '仁武', 3, '2022-08-16 10:00:00'],
#  ['高雄市', '鳳山', 6, '2022-08-16 10:00:00'],
#  ['高雄市', '大寮', 5, '2022-08-16 10:00:00'],
#  ['高雄市', '林園', 2, '2022-08-16 10:00:00'],
#  ['高雄市', '楠梓', 2, '2022-08-16 10:00:00'],
#  ['高雄市', '左營', 0, '2022-08-16 10:00:00'],
#  ['高雄市', '前金', 3, '2022-08-16 10:00:00'],
#  ['高雄市', '前鎮', 2, '2022-08-16 10:00:00'],
#  ['高雄市', '小港', 6, '2022-08-16 10:00:00'],
#  ['屏東縣', '屏東', 10, '2022-08-16 10:00:00'],
#  ['屏東縣', '潮州', 11, '2022-08-16 10:00:00'],
#  ['屏東縣', '恆春', 2, '2022-08-16 10:00:00'],
#  ['臺東縣', '臺東', 2, '2022-08-16 10:00:00'],
#  ['花蓮縣', '花蓮', 3, '2022-08-16 10:00:00'],
#  ['臺北市', '陽明', 9, '2022-08-16 10:00:00'],
#  ['宜蘭縣', '宜蘭', 8, '2022-08-16 10:00:00'],
#  ['宜蘭縣', '冬山', 0, '2022-08-16 10:00:00'],
#  ['新北市', '三重', 15, '2022-08-16 10:00:00'],
#  ['桃園市', '中壢', 11, '2022-08-16 10:00:00'],
#  ['南投縣', '竹山', 3, '2022-08-16 10:00:00'],
#  ['新北市', '永和', 15, '2022-08-16 10:00:00'],
#  ['高雄市', '復興', 3, '2022-08-16 10:00:00'],
#  ['南投縣', '埔里', 9, '2022-08-16 10:00:00'],
#  ['新北市', '富貴角', 3, '2022-08-16 10:00:00'],
#  ['臺東縣', '關山', 0, '2022-08-16 10:00:00'],
#  ['金門縣', '金門', 0, '2022-08-16 10:00:00'],
#  ['連江縣', '馬祖', 7, '2022-08-16 10:00:00'],
#  ['澎湖縣', '馬公', 8, '2022-08-16 10:00:00'],
#  ['雲林縣', '麥寮', 1, '2022-08-16 10:00:00']]

# %%
df=pd.DataFrame(values,columns=['city','stationName','result','resultTime'])
df
# Out:
#    city stationName  result           resultTime
# 0   基隆市          基隆       4  2022-08-16 10:00:00
# 1   新北市          汐止       8  2022-08-16 10:00:00
# 2   新北市          萬里       6  2022-08-16 10:00:00
# 3   新北市          新店      14  2022-08-16 10:00:00
# 4   新北市          土城      13  2022-08-16 10:00:00
# ..  ...         ...     ...                  ...
# 72  臺東縣          關山       0  2022-08-16 10:00:00
# 73  金門縣          金門       0  2022-08-16 10:00:00
# 74  連江縣          馬祖       7  2022-08-16 10:00:00
# 75  澎湖縣          馬公       8  2022-08-16 10:00:00
# 76  雲林縣          麥寮       1  2022-08-16 10:00:00
#
# [77 rows x 4 columns]

# %%
df['resultTime'].apply(pd.to_datetime)
# Out:
# 0    2022-08-16 10:00:00
# 1    2022-08-16 10:00:00
# 2    2022-08-16 10:00:00
# 3    2022-08-16 10:00:00
# 4    2022-08-16 10:00:00
#              ...
# 72   2022-08-16 10:00:00
# 73   2022-08-16 10:00:00
# 74   2022-08-16 10:00:00
# 75   2022-08-16 10:00:00
# 76   2022-08-16 10:00:00
# Name: resultTime, Length: 77, dtype: datetime64[ns]

# %%
df
# Out:
#    city stationName  result           resultTime
# 0   基隆市          基隆       4  2022-08-16 10:00:00
# 1   新北市          汐止       8  2022-08-16 10:00:00
# 2   新北市          萬里       6  2022-08-16 10:00:00
# 3   新北市          新店      14  2022-08-16 10:00:00
# 4   新北市          土城      13  2022-08-16 10:00:00
# ..  ...         ...     ...                  ...
# 72  臺東縣          關山       0  2022-08-16 10:00:00
# 73  金門縣          金門       0  2022-08-16 10:00:00
# 74  連江縣          馬祖       7  2022-08-16 10:00:00
# 75  澎湖縣          馬公       8  2022-08-16 10:00:00
# 76  雲林縣          麥寮       1  2022-08-16 10:00:00
#
# [77 rows x 4 columns]

# %% [markdown]
# ### 取得六都得平均值
# - 臺北市，新北市，桃園市，臺中市，臺南市，高雄市

# %%
df['city']
# Out:
# 0     基隆市
# 1     新北市
# 2     新北市
# 3     新北市
# 4     新北市
#      ...
# 72    臺東縣
# 73    金門縣
# 74    連江縣
# 75    澎湖縣
# 76    雲林縣
# Name: city, Length: 77, dtype: object

# %%
six_cities=['臺北市','新北市','桃園市','臺中市','臺南市','高雄市']

# %%
cities=[]
results=[]
for city in six_cities:
    result=round(df.groupby('city').get_group(city)['result'].mean(),1)
    print(city,result)
    cities.append(city)
    results.append(result)

cities,results
# Out:
# 臺北市 15.7
# 新北市 10.5
# 桃園市 8.2
# 臺中市 6.4
# 臺南市 8.8
# 高雄市 3.8
# (['臺北市', '新北市', '桃園市', '臺中市', '臺南市', '高雄市'], [15.7, 10.5, 8.2, 6.4, 8.8, 3.8])
